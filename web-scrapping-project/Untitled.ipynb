# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
names = ['Alex Hales', 'Agha Salman', 'Colin Munro', 'Faheem Ashraf', 'Jordan Cox', 'Imad Wasim']
df = pd.read_csv('data.csv')
data = df[df['Name'].isin(names)]
data
# Out:
#         Match_ID       ID        Name  Runs  Balls   4s   6s      SR  \
# 30875    1416486   227758  Imad Wasim   0.0    2.0  0.0  0.0    0.00
# 30876    1416484   227758  Imad Wasim   1.0    3.0  0.0  0.0   33.33
# 30877    1416479   227758  Imad Wasim   9.0   15.0  0.0  0.0   60.00
# 30878    1416476   227758  Imad Wasim   0.0    3.0  0.0  0.0    0.00
# 30879    1416472   227758  Imad Wasim   NaN    NaN  NaN  NaN     NaN
# ...          ...      ...         ...   ...    ...  ...  ...     ...
# 197243   1167185  1112537  Jordan Cox   7.0   11.0  1.0  0.0   63.63
# 197244   1167171  1112537  Jordan Cox  23.0   17.0  3.0  0.0  135.29
# 197245   1167154  1112537  Jordan Cox  11.0    9.0  0.0  0.0  122.22
# 197246   1167141  1112537  Jordan Cox  10.0   11.0  1.0  0.0   90.90
# 197247   1167137  1112537  Jordan Cox   7.0   10.0  0.0  0.0   70.00
#
#                     Team  Overs  Wicket  Maiden  Economy   WB   NB  row_num
# 30875   Islamabad United    4.0     1.0     0.0     5.00  0.0  0.0        1
# 30876   Islamabad United    1.0     0.0     0.0    17.00  0.0  0.0        2
# 30877   Islamabad United    2.0     0.0     0.0    11.50  1.0  0.0        3
# 30878   Islamabad United    4.0     1.0     0.0     5.50  0.0  0.0        4
# 30879                NaN    4.0     0.0     0.0     8.25  2.0  0.0        5
# ...                  ...    ...     ...     ...      ...  ...  ...      ...
# 197243              Kent    NaN     NaN     NaN      NaN  NaN  NaN      116
# 197244              Kent    NaN     NaN     NaN      NaN  NaN  NaN      117
# 197245              Kent    NaN     NaN     NaN      NaN  NaN  NaN      118
# 197246              Kent    NaN     NaN     NaN      NaN  NaN  NaN      119
# 197247              Kent    NaN     NaN     NaN      NaN  NaN  NaN      120
#
# [1422 rows x 16 columns]

# %%
plt.figure(figsize=(16,8))
sns.set_style('darkgrid')
sns.boxenplot(data=data, y='Runs', x='Name', hue='Name')
plt.show()
