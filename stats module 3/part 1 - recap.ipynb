# %% [markdown]
# # Lesson 1: Central Tendency and Measures of Dispersion
# ## Central Tendencies
# * Central Tendency:
# Evaluate a point estimate for the data
# * Mean:
# Average value in the data
# * Median:
# Middle value in the data
# * Mode:
# Value with highest frequency in the data
#
# ## Measures of Variability
# * Variance is average degree to which each data point differs from the mean.
# * Standard Deviation is simply the square root of variance.
# * Range is difference between max and min of the data.
# * Quartile simply divides the observations in data into 4 equal intervals or quarters which are more or less of equal size.
# * Interquartile range is difference between 75th percentile and 25th percentile.

# %% [markdown]
# ## Sales analysis by marketing channel
#
# ### Problem:
# The sales department of the company is interested in understanding the mode of channel with consistent performance in sales (thousand $). They are also interested in channels where we have received some extreme sales (thousand §) over the course of past 7 years.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset

# %%
data = {'Facebook': [634.5891, 660.0033, 1320.943, 928.5687, 822.2156, 1113.621, 1070.288],
    'Twitter': [1044.49576, 787.20264, 876.070118, 975.64292, 1077.91376, 812.00987, 987.447021],
    'Email': [1939.04032, 708.189888, 702.39168, 1167.98208, 1100.15712, 1352.77056, 608.33952],
    'Phone': [807.077136, 659.3432967, 1184.885871, 925.7829939, 819.7489532, 1110.280137, 1067.0771361]}
data = pd. DataFrame(data)

# Show the data
data
# Out:
#     Facebook      Twitter        Email        Phone
# 0   634.5891  1044.495760  1939.040320   807.077136
# 1   660.0033   787.202640   708.189888   659.343297
# 2  1320.9430   876.070118   702.391680  1184.885871
# 3   928.5687   975.642920  1167.982080   925.782994
# 4   822.2156  1077.913760  1100.157120   819.748953
# 5  1113.6210   812.009870  1352.770560  1110.280137
# 6  1070.2880   987.447021   608.339520  1067.077136

# %% [markdown]
# ### Satatusctical summary of the dataset

# %%
data.describe()
# Out:
#           Facebook      Twitter        Email        Phone
# count     7.000000     7.000000     7.000000     7.000000
# mean    935.746957   937.254584  1082.695881   939.170789
# std     250.927604   113.448947   469.706423   189.827690
# min     634.589100   787.202640   608.339520   659.343297
# 25%     741.109450   844.039994   705.290784   813.413045
# 50%     928.568700   975.642920  1100.157120   925.782994
# 75%    1091.954500  1015.971390  1260.376320  1088.678637
# max    1320.943000  1077.913760  1939.040320  1184.885871

# %% [markdown]
# # Lesson 2: Exploratory Data Analysis
# * Exploratory data analysis is a process of exploring and summarising data sets to understand their main characteristics and patterns. That is, it summarises the main characteristics of the data and helps you discover relationships between the variables.
#
# * EDA is important in statistical analysis because it helps you get a better understanding of your data. You can identify the most relevant variables, detect outliers and errors and more. In addition, it can help you communicate your findings effectively.
#
# ## Techniques in Exploratory Data Analysis
#
# ### Graphical
# * Univariate
# * Bivariate
# ### Non Graphical
#
# * Univariate
# * Bivariate

# %% [markdown]
# ## Benefits of EDA
# * Better understanding of data.
# * Visual representation of data.
# * Helps identifying distributions and patterns in data.
# * Helps identifying issues like outliers, null values, duplicates, etc.
#
# ### Let's extend our understanding of EDA
# #### Univariate analysis: Type of Visualization
# * Categorical:
# Bar charts, count plots, pie charts
# * Continuous
# Box plots, histograms
# #### Bivariate analysis: Type of Visualization
# * Categorical:
# Cross tabs, heatmaps
# Bar plots, line plots, pie charts, stacked charts
# * Continuous:
# Bar plots, line plots, pie charts, stacked charts
# Scatter plots

# %% [markdown]
# ## Sales analysis by marketing channel
# ### Problem:
# The sales department of the company is interested in understanding the distributions and relationships present within the sales data for last 7 years.
# Please provide quick insights from the data provided.
# Invac
#
# ### Univariate analysis

# %%
# Create 4 figure for plots
fig, (a,b,c,d) = plt.subplots(1, 4, figsize=(15, 5))
sns.set_style('darkgrid')
plots = [a,b,c,d]

media = ['Facebook', 'Twitter', 'Email', 'Phone']

for i, plot in enumerate(plots):
    sns.boxplot(y=data[media[i]], ax=plot)
    plot.set_title(media[i])
    plot.set_ylabel('Sales in Thousand')

plt.tight_layout() 
plt.show()

# %%
# Comparison 
plt.figure(figsize=(16,8))
sns.set_style('darkgrid')
sns.boxplot(data)

plt.show()

# %% [markdown]
# ### Bivariate Analysis
# #### Correlation Analysis
# It defines association between numerical variables and is bounded in range of -1 to 1 where,
# * a. -1 to 0 defines inversely proportional relationship
# * b. 0 to 1 defines directly proportional relationships.
# * c. O or close to 0 in this case defines no such relationship.

# %%
corr = data[['Facebook', 'Twitter', 'Email', 'Phone']].corr()
# Create a heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(corr, annot=True, vmin=-1, vmax=1, cmap=sns.cubehelix_palette(as_cmap=True, rot=.2), center=0, fmt=".2f")
plt.title("Correlation Heatmap", fontweight='bold')
plt.show()

# %%
sns.pairplot(data[['Facebook', 'Twitter', 'Email', 'Phone']])
plt.show()

# %% [markdown]
# # Lesson 3: Outlier Detection and Treatment of outliers
# ## What are outliers?
# Outliers are set of extreme values that stand significantly different from other observations in a dataset. These can be caused by data entry errors, measurement errors, collection of sample errors and natural variation.
#
# ## Outlier detection
# ### Percentile rule
# * Upper cut off = p99
# * Lower cut off = p1
#
# ### Z - Score rule
# * Upper cut off = mean + 2.5 SD
# * Lower cut off = Mean - 2.5 SD
#
# ### IQR rule
# * Upper cut off =
# 03 + 1.5 * IQR
# * Lower cut off =
# Q1 - 1.5 * 1QR

# %% [markdown]
# ## Outlier detection and treatment
#
# ### Problem:
# The HR department is interested to understand the employee information present in their people analytics platform. They want to clean the messy data at their end where they have witnessed outliers in the past. Help them carrying out this task.

# %%
df = {'Employee ID': ['E01', 'E02', 'Е03', 'Е04', 'Е05', 'Е06', 'Е07'],
    'Age': [30,53,42,29,95,36,52],
    'Salary': [0.781571617,0.2484892,2.997425024,0.370216911,0.574881814,0.930060076,0.643781331],
    'Years of Experience': [5,50,14,18,35,10,24]}
df = pd.DataFrame(df)
df
# Out:
#   Employee ID  Age    Salary  Years of Experience
# 0         E01   30  0.781572                    5
# 1         E02   53  0.248489                   50
# 2         Е03   42  2.997425                   14
# 3         Е04   29  0.370217                   18
# 4         Е05   95  0.574882                   35
# 5         Е06   36  0.930060                   10
# 6         Е07   52  0.643781                   24

# %% [markdown]
# ## Detecting outliers with boxplots

# %%
# Creating subplots for 3 columns
fig, axs = plt.subplots(1,3, figsize=(16,6))

# columns for box plots
columns = ['Age', 'Salary', 'Years of Experience']

# Boxplot
for i, column in enumerate(columns):
    sns.boxplot(y=df[column], ax=axs[i])
    axs[i].set_title(column, fontsize=16, fontweight='bold')

# %% [markdown]
# ### Outcome from Boxplots
# * in Age column there is a value greater than 90. which is very rare case. so it might be outlier
# * in Salary column there is a value around 3. which is very far from range and it might be outlier
# * There is not any outlier presen in Years of Experience column

# %% [markdown]
# ### Detect outliers with 3 methods

# %%
# Percentile method
def percentile_method(data, col):
    lower = data[col].quantile(0.01)
    upper = data[col].quantile(0.99)
    outliers = data[(data[col] < lower) | (data[col] > upper)]
    return outliers

percentile_method(df, 'Age')
# Out:
#   Employee ID  Age    Salary  Years of Experience
# 3         Е04   29  0.370217                   18
# 4         Е05   95  0.574882                   35
