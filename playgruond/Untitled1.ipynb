# %%
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error

# List of scores for the last 100 matches
last_100_matches_scores = [20, 15, 60, 40, 70, 25, 50, 80, 30, 65,
                           45, 75, 35, 55, 85, 90, 95, 100, 50, 25,
                           70, 60, 80, 40, 65, 55, 75, 45, 85, 35,
                           95, 30, 50, 70, 40, 60, 80, 90, 35, 65,
                           25, 55, 45, 75, 85, 95, 100, 50, 70, 40,
                           80, 60, 90, 35, 65, 25, 55, 45, 75, 85,
                           95, 100, 50, 70, 40, 80, 60, 90, 35, 65,
                           25, 55, 45, 75, 85, 95, 100, 50, 70, 40,
                           80, 60, 90, 35, 65, 25, 55, 45, 75, 85]

# Prepare data
window_size = 5  # Number of previous matches to consider
X = []
y = []
for i in range(len(last_100_matches_scores) - window_size):
    X.append(last_100_matches_scores[i:i + window_size])
    y.append(last_100_matches_scores[i + window_size])

# Split data into training and testing sets
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Define and train MLP regressor
model = MLPRegressor(hidden_layer_sizes=(50,), activation='relu', solver='adam', max_iter=1000, random_state=0)
model.fit(X_train, y_train)

# Make predictions for the 101st match
last_five_matches = last_100_matches_scores[-5:]  # Scores of last 5 matches
prediction = model.predict([last_five_matches])
print("Predicted score for the 101st match:", prediction[0])
# Out:
# Predicted score for the 101st match: 79.59403084818221
# /Users/tariqahamad/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df.drop(columns='row_num', inplace=True)
df.drop_duplicates()
player_runs = df[df['Name'] == 'Virat Kohli']['Runs']
player_runs
# Out:
# 40562      0.0
# 40563     29.0
# 40564    101.0
# 40565    100.0
# 40566     18.0
# 40567      1.0
# 40568     55.0
# 40569     31.0
# 40570     54.0
# 40571      0.0
# 40572     59.0
# 40573      6.0
# 40574     50.0
# 40575     61.0
# 40576     21.0
# 40577     82.0
# 40578     19.0
# 40579     49.0
# 40580      3.0
# 40581     63.0
# 40582     11.0
# 40583      2.0
# 40584    122.0
# 40585      0.0
# 40586     60.0
# 40587     59.0
# 40588     35.0
# 40589      7.0
# 40590     25.0
# 40591     73.0
# 40592     20.0
# 40593      0.0
# 40594     30.0
# 40595     58.0
# 40596      9.0
# 40597      0.0
# 40598      0.0
# 40599     12.0
# 40600      1.0
# 40601     48.0
# 40602      5.0
# 40603     12.0
# 40604     41.0
# 40605     50.0
# 40606     26.0
# 40607     64.0
# 40608     12.0
# 40609     62.0
# 40610     82.0
# 40611      NaN
# 40612     11.0
# 40613     23.0
# 40614     23.0
# 40615     23.0
# 40616     23.0
# 40617     23.0
# 40618     23.0
# 40619     23.0
# ...

# %%
df
# Out:
#         Match_ID       ID            Name  Runs  Balls   4s   6s      SR  \
# 0         959211     4068     Jim Allenby  31.0   29.0  4.0  0.0  106.89
# 1         959199     4068     Jim Allenby   7.0   11.0  1.0  0.0   63.63
# 2         743933     4068     Jim Allenby  28.0   27.0  7.0  0.0  103.70
# 3        1217133     4292     Travis Birt   4.0    5.0  1.0  0.0   80.00
# 4        1195629     4451   George Bailey  13.0    7.0  3.0  0.0  185.71
# ...          ...      ...             ...   ...    ...  ...  ...     ...
# 226872   1418183  1418086   Mukesh Thakur   7.0    7.0  1.0  0.0  100.00
# 226873   1418544  1420901  Shenjian Zheng  23.0   11.0  1.0  2.0  209.09
# 226874   1418543  1420901  Shenjian Zheng  21.0   13.0  2.0  2.0  161.53
# 226875   1418541  1420901  Shenjian Zheng   6.0   13.0  1.0  0.0   46.15
# 226876   1418539  1420901  Shenjian Zheng   1.0    3.0  0.0  0.0   33.33
#
#                      Team  Overs  Wicket  Maiden  Economy   WB   NB  row_num
# ...

# %%
pd.set_option('display.max_rows', None)
sorted_runs = player_runs.sort_index(ascending=False)
sorted_runs
# Out:
# 40873     13.0
# 40872     41.0
# 40871     18.0
# 40870     51.0
# 40869     62.0
# 40868     35.0
# 40867      1.0
# 40866     34.0
# 40865     48.0
# 40864     32.0
# 40863     82.0
# 40862     19.0
# 40861     44.0
# 40860      1.0
# 40859     12.0
# 40858     12.0
# 40857     14.0
# 40856     14.0
# 40855     14.0
# 40854     14.0
# 40853     14.0
# 40852     14.0
# 40851      1.0
# 40850     23.0
# 40849     25.0
# 40848     16.0
# 40847      8.0
# 40846    103.0
# 40845     78.0
# 40844     78.0
# 40843     78.0
# 40842     78.0
# 40841     78.0
# 40840     78.0
# 40839     78.0
# 40838     18.0
# 40837     90.0
# 40836     59.0
# 40835     50.0
# 40834     43.0
# 40833      1.0
# 40832      7.0
# 40831     49.0
# 40830     56.0
# 40829     41.0
# 40828     75.0
# 40827     79.0
# 40826     33.0
# 40825     80.0
# 40824    100.0
# 40823     14.0
# 40822     52.0
# 40821    108.0
# 40820     20.0
# 40819      7.0
# 40818    109.0
# 40817     75.0
# 40816    113.0
# ...

# %%
# List of scores for the last 100 matches
last_100_matches_scores = [13, 41, 18, 51, 62, 35, 1, 34, 48, 32, 82, 19, 44, 1, 
                           12, 12, 14, 14, 14, 14, 14, 14, 1, 23, 25, 16, 8, 103, 78, 
                           78, 78, 78, 78, 78, 78, 18, 90, 59, 50, 43, 1, 7, 49, 56, 
                           41, 75, 79, 33, 80, 100, 14, 52, 108, 20, 7, 109, 75, 113, 
                           54, 0, 54, 29, 21, 2, 16, 62, 28, 64, 0, 10, 55, 20, 6, 5, 
                           58, 39, 82, 22, 0, 20, 47, 43, 26, 65, 13, 26, 1, 31, 21, 57, 
                           92, 30, 18, 68, 32, 8, 39, 70, 48, 12, 4, 0, 9, 18, 82, 77, 
                           67, 72, 66, 26, 34, 1, 4, 61, 3, 123, 82, 82, 82, 82, 82, 82, 
                           82, 23, 23, 23, 23, 23, 23, 23, 3, 104, 46, 45, 43, 60, 139, 
                           139, 139, 139, 139, 139, 139, 45, 140, 157, 107, 16, 33, 64, 
                           44, 116, 123, 7, 20, 24, 72, 18, 47, 6, 46, 3, 23, 84, 41, 67, 
                           8, 100, 9, 13, 23, 25, 16, 72, 9, 94, 19, 70, 45, 11, 38, 11, 
                           19, 28, 59, 30, 26, 18, 9, 7, 29, 1, 72, 43, 43, 90, 48, 14, 
                           33, 50, 3, 9, 40, 85, 6, 0, 73, 77, 1, 80, 33, 33, 5, 72, 8, 
                           12, 35, 5, 25, 5, 4, 25, 51, 53, 39, 57, 9, 2, 1, 11, 35, 79, 
                           51, 0, 65, 0, 0, 0, 0, 0, 0, 0, 8, 18, 0, 17, 52, 45, 45, 45, 
                           45, 45, 45, 45, 23, 23, 23, 23, 23, 23, 23, 11, 82, 62, 12, 64, 
                           26, 50, 41, 12, 5, 48, 1, 12, 0, 0, 9, 58, 30, 0, 20, 73, 25, 
                           7, 35, 59, 60, 0, 122, 2, 11, 63, 3, 49, 19, 82, 21,
                          61, 50, 6, 59, 0, 54, 31, 55, 1, 18, 100, 101, 29]

# Prepare data
window_size = 5  # Number of previous matches to consider
X = []
y = []
for i in range(len(last_100_matches_scores) - window_size):
    X.append(last_100_matches_scores[i:i + window_size])
    y.append(last_100_matches_scores[i + window_size])

# Split data into training and testing sets
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Define and train MLP regressor
model = MLPRegressor(hidden_layer_sizes=(50,), activation='relu', solver='adam', max_iter=1000, random_state=0)
model.fit(X_train, y_train)

# Make predictions for the 101st match
last_five_matches = last_100_matches_scores[-5:]  # Scores of last 5 matches
prediction = model.predict([last_five_matches])
print("Predicted score for the 101st match:", prediction[0])
# Out:
# Predicted score for the 101st match: 64.03440798237878
